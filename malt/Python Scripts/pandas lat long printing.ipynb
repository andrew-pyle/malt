# %%
import pandas as pd

# %%
df = pd.read_json("data.json")

# %%
df.columns.values
# Out:
# array(['Account Name', 'City', 'Country', 'Date', 'Date and Time', 'Hour',
#        'IP Address', 'Latitude', 'Location', 'Longitude', 'State', 'Time',
#        'Time Stamp', 'Time Zone'], dtype=object)

# %%
df.iterrows()
# Out:
# <generator object DataFrame.iterrows at 0x10616e0f8>

# %%
for index, row in df.iterrows():
    print(row['Account Name'])
# Out:
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx
# xxxxxxxxxxxx

# %%
for column in df:
    print(column)
# Out:
# Account Name
# City
# Country
# Date
# Date and Time
# Hour
# IP Address
# Latitude
# Location
# Longitude
# State
# Time
# Time Stamp
# Time Zone

# %%
list(df['Latitude'].values)[0]
# Out:
# 34.564537199999997

# %%
latlist = []
longlist []
latlonglist = []

for x in list(df['Latitude']):
    latlist.append(x) 

latlonglist
# Out:
# [34.564537199999997,
#  34.564537199999997,
#  35.088696300000002,
#  35.472988600000001,
#  39.046129200000003,
#  39.046129200000003,
#  39.046129200000003,
#  34.746480900000002,
#  34.746480900000002,
#  34.746480900000002,
#  34.746480900000002,
#  34.746480900000002,
#  34.974531999999996,
#  38.8051095,
#  34.746480900000002,
#  34.729846999999999,
#  34.729846999999999,
#  32.776271899999998,
#  34.065846000000001,
#  34.746480900000002,
#  34.746480900000002,
#  32.776271899999998,
#  39.046129200000003,
#  39.046129200000003,
#  33.584558200000004,
#  32.776271899999998,
#  32.776271899999998,
#  32.776271899999998,
#  32.776271899999998,
#  39.575263900000003,
#  34.746480900000002,
#  33.629342700000002,
#  34.746480900000002,
#  34.729846999999999,
#  34.729846999999999]

# %%
df[['Latitude', 'Longitude']].values.tolist()
# Out:
# [[34.5645372, -92.5868279],
#  [34.5645372, -92.5868279],
#  [35.0886963, -92.442101],
#  [35.4729886, -97.5170535],
#  [39.0461292, -77.1130096],
#  [39.0461292, -77.1130096],
#  [39.0461292, -77.1130096],
#  [34.7464809, -92.2895947],
#  [34.7464809, -92.2895947],
#  [34.7464809, -92.2895947],
#  [34.7464809, -92.2895947],
#  [34.7464809, -92.2895947],
#  [34.974531999999996, -92.0165335],
#  [38.8051095, -77.0470228],
#  [34.7464809, -92.2895947],
#  [34.729847, -86.585901],
#  [34.729847, -86.585901],
#  [32.7762719, -96.7968558],
#  [34.065846, -117.6484303],
#  [34.7464809, -92.2895947],
#  [34.7464809, -92.2895947],
#  [32.7762719, -96.7968558],
#  [39.0461292, -77.1130096],
#  [39.0461292, -77.1130096],
#  [33.584558200000004, -92.8343293],
#  [32.7762719, -96.7968558],
#  [32.7762719, -96.7968558],
#  [32.7762719, -96.7968558],
#  [32.7762719, -96.7968558],
#  [39.5752639, -76.9959276],
#  [34.7464809, -92.2895947],
#  [33.6293427, -91.7912326],
# ...

# %%
df['Latitude'].values.tolist()
# Out:
# [34.5645372,
#  34.5645372,
#  35.0886963,
#  35.4729886,
#  39.0461292,
#  39.0461292,
#  39.0461292,
#  34.7464809,
#  34.7464809,
#  34.7464809,
#  34.7464809,
#  34.7464809,
#  34.974531999999996,
#  38.8051095,
#  34.7464809,
#  34.729847,
#  34.729847,
#  32.7762719,
#  34.065846,
#  34.7464809,
#  34.7464809,
#  32.7762719,
#  39.0461292,
#  39.0461292,
#  33.584558200000004,
#  32.7762719,
#  32.7762719,
#  32.7762719,
#  32.7762719,
#  39.5752639,
#  34.7464809,
#  33.6293427,
#  34.7464809,
#  34.729847,
#  34.729847]

# %%
df[['Account Name','City','State','Date','IP Address']].values.tolist()
# Out:
# [['xxxxxxxxxxxx',
#   'Benton',
#   'Arkansas',
#   Timestamp('2017-03-23 00:00:00'),
#   '108.64.45.187'],
#  ['xxxxxxxxxxxx',
#   'Benton',
#   'Arkansas',
#   Timestamp('2017-01-08 00:00:00'),
#   '108.64.45.187'],
#  ['xxxxxxxxxxxx',
#   'Conway',
#   'Arkansas',
#   Timestamp('2017-01-08 00:00:00'),
#   '24.144.24.103'],
#  ['xxxxxxxxxxxx',
#   'Oklahoma City',
#   'Oklahoma',
#   Timestamp('2017-01-08 00:00:00'),
#   '166.173.62.123'],
#  ['xxxxxxxxxxxx',
#   'North Bethesda',
#   'Maryland',
#   Timestamp('2017-01-08 00:00:00'),
#   '73.133.196.202'],
#  ['xxxxxxxxxxxx',
#   'North Bethesda',
#   'Maryland',
#   Timestamp('2017-01-08 00:00:00'),
#   '73.133.196.202'],
#  ['xxxxxxxxxxxx',
#   'North Bethesda',
#   'Maryland',
#   Timestamp('2017-01-08 00:00:00'),
#   '73.133.196.202'],
#  ['xxxxxxxxxxxx',
#   'Little Rock',
#   'Arkansas',
#   Timestamp('2017-01-08 00:00:00'),
#   '2601:381:8101:1b0f:d066:4f15:899b:dc49'],
#  ['xxxxxxxxxxxx',
#   'Little Rock',
#   'Arkansas',
# ...

# %%
markers = df[['Account Name','City','State','Date','IP Address','Latitude','Longitude']].values.tolist()

# %%
# array(['Account Name', 'City', 'Country', 'Date', 'Date and Time', 'Hour',
#        'IP Address', 'Latitude', 'Location', 'Longitude', 'State', 'Time',
#        'Time Stamp', 'Time Zone'], dtype=object)

for row in markers:
    popup = "{}\n{}\n{}\n{}\n{}".format(row[0], row[1], row[2], row[3], row[4])
    latlong = [row[5], row[6]]
    print(popup)
# Out:
# xxxxxxxxxxxx
# Benton
# Arkansas
# 2017-03-23 00:00:00
# 108.64.45.187
# xxxxxxxxxxxx
# Benton
# Arkansas
# 2017-01-08 00:00:00
# 108.64.45.187
# xxxxxxxxxxxx
# Conway
# Arkansas
# 2017-01-08 00:00:00
# 24.144.24.103
# xxxxxxxxxxxx
# Oklahoma City
# Oklahoma
# 2017-01-08 00:00:00
# 166.173.62.123
# xxxxxxxxxxxx
# North Bethesda
# Maryland
# 2017-01-08 00:00:00
# 73.133.196.202
# xxxxxxxxxxxx
# North Bethesda
# Maryland
# 2017-01-08 00:00:00
# 73.133.196.202
# xxxxxxxxxxxx
# North Bethesda
# Maryland
# 2017-01-08 00:00:00
# 73.133.196.202
# xxxxxxxxxxxx
# Little Rock
# Arkansas
# 2017-01-08 00:00:00
# 2601:381:8101:1b0f:d066:4f15:899b:dc49
# xxxxxxxxxxxx
# Little Rock
# Arkansas
# 2017-01-08 00:00:00
# 2601:381:8101:1b0f:d066:4f15:899b:dc49
# xxxxxxxxxxxx
# Little Rock
# Arkansas
# 2017-01-08 00:00:00
# 2601:381:8101:1b0f:d066:4f15:899b:dc49
# xxxxxxxxxxxx
# Little Rock
# Arkansas
# 2017-01-08 00:00:00
# 2601:381:8101:1b0f:d066:4f15:899b:dc49
# xxxxxxxxxxxx
# Little Rock
# Arkansas
# ...

# %%
for key,value in df.iterrows():
    print(key, value)
# Out:
# 0 Account Name                                          xxxxxxxxxxxx
# City                                                        Benton
# Country                                              United States
# Date                                           2017-03-23 00:00:00
# Date and Time    Sunday, January 8, 2017 at 7:46:32 AM Central ...
# Hour                                                             7
# IP Address                                           108.64.45.187
# Latitude                                                   34.5645
# Location                           Benton, Arkansas, United States
# Longitude                                                 -92.5868
# State                                                     Arkansas
# Time                                                      07:46:32
# Time Stamp                                           1483861592000
# Time Zone                                    Central Standard Time
# Name: 0, dtype: object
# ...

# %%
url_args = {
    'radius': 100,
}

# %%
url_args['radius']
# Out:
# 100
